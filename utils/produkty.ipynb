# %%
import pandas as pd
import polars as pl
import duckdb

# %%
df = pl.read_csv('produkty.csv', truncate_ragged_lines=True, separator=';')

# %%
df
# Out:
# shape: (37, 6)
# ┌──────────────┬─────────────────────────────────┬─────────┬──────┬───────────┬───────────────────┐
# │ kod_produktu ┆ nazov                           ┆ rozmer  ┆ cena ┆ popis     ┆ farba             │
# │ ---          ┆ ---                             ┆ ---     ┆ ---  ┆ ---       ┆ ---               │
# │ str          ┆ str                             ┆ str     ┆ str  ┆ str       ┆ str               │
# ╞══════════════╪═════════════════════════════════╪═════════╪══════╪═══════════╪═══════════════════╡
# │ vd001        ┆ Spomíname                       ┆ 12 cm   ┆ 0,40 ┆ spomíname ┆ čierna,sivá,hnedá │
# │ vd002        ┆ Spomíname                       ┆ 17 cm   ┆ 0,65 ┆ null      ┆ null              │
# │ vd003        ┆ S láskou spomíname anjel        ┆ 12 cm   ┆ 0,75 ┆ null      ┆ null              │
# │ vd004        ┆ Srdce s láskou spomíname        ┆ 11 cm   ┆ 1,05 ┆ null      ┆ null              │
# ...

# %%
df = df.drop('farba')

# %%
df
# Out:
# shape: (37, 5)
# ┌──────────────┬─────────────────────────────────┬─────────┬──────┬───────────┐
# │ kod_produktu ┆ nazov                           ┆ rozmer  ┆ cena ┆ popis     │
# │ ---          ┆ ---                             ┆ ---     ┆ ---  ┆ ---       │
# │ str          ┆ str                             ┆ str     ┆ str  ┆ str       │
# ╞══════════════╪═════════════════════════════════╪═════════╪══════╪═══════════╡
# │ vd001        ┆ Spomíname                       ┆ 12 cm   ┆ 0,40 ┆ spomíname │
# │ vd002        ┆ Spomíname                       ┆ 17 cm   ┆ 0,65 ┆ null      │
# │ vd003        ┆ S láskou spomíname anjel        ┆ 12 cm   ┆ 0,75 ┆ null      │
# │ vd004        ┆ Srdce s láskou spomíname        ┆ 11 cm   ┆ 1,05 ┆ null      │
# │ vd005        ┆ S láskou spomíname list + srdc… ┆ 15 cm   ┆ 1,35 ┆ null      │
# │ …            ┆ …                               ┆ …       ┆ …    ┆ …         │
# ...

# %%
df = df.to_pandas()

# %%
df.iloc[25:29, -1] = 'c'

# %%
df
# Out:
#    kod_produktu                            nazov    rozmer  cena      popis  \
# 0         vd001                        Spomíname     12 cm  0,40  spomíname
# 1         vd002                        Spomíname     17 cm  0,65       None
# 2         vd003         S láskou spomíname anjel     12 cm  0,75       None
# 3         vd004         Srdce s láskou spomíname     11 cm  1,05       None
# 4         vd005  S láskou spomíname list + srdce     15 cm  1,35       None
# 5         vd006                   Kríž spomíname     15 cm  1,15       None
# 6         vd007               Odpočívaj v pokoji     12 cm  0,80       None
# 7         vd008              Kríž spomíname malý     10 cm  0,55       None
# 8         vd009                       Chýbaš nám     12 cm  0,75       None
# 9         vd010                      Chýbate nám     12 cm  0,75       None
# 10        vd011          Spomíname ceduľka tip 1     12 cm  0,80       None
# ...

# %%
df.to_csv('produkty.csv', index=False)
